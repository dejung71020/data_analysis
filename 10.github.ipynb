# %%
# !git clone https://github.com/dejung71020/data_analysis.git
# Out:
# Cloning into 'data_analysis'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 1), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 8.16 KiB | 4.08 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# !pwd
# Out:
# /content

# %%
# !cp /content/drive/MyDrive/랭체인 AI 영상객체탐지분석 플랫폼 구축/9. 데이터분석/*.ipynb /content/data_analysis
